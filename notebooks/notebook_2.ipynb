# %%
print("this is a notebook")
# Out:
# this is a notebook

# %%
spark.sql("SELECT 1").show()
# Out:
# ---------------------------------------------------------------------------
# SparkConnectGrpcException                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 spark.sql("SELECT 1").show()
#
# File c:\Users\TBR44\Desktop\databricks\dab\dab_project\.venv_dbc\Lib\site-packages\pyspark\sql\connect\session.py:736, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#     733         _views.append(SubqueryAlias(df._plan, name))
#     735 cmd = SQL(sqlQuery, _args, _named_args, _views)
# --> 736 data, properties, ei = self.client.execute_command(cmd.command(self._client))
#     737 if "sql_command_result" in properties:
#     738     df = DataFrame(CachedRelation(properties["sql_command_result"]), self)
#
# File c:\Users\TBR44\Desktop\databricks\dab\dab_project\.venv_dbc\Lib\site-packages\pyspark\sql\connect\client\core.py:1297, in SparkConnectClient.execute_command(self, command, observations, extra_request_metadata)
# ...
